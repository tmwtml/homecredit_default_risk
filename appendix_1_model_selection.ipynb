# %% [markdown]
# # Appendix 1: Model Selection Process
#
# Explore model based on application features only

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd.options.display.max_columns = None
pd.set_option('display.float_format', '{:.4f}'.format)

# %%
data_path = 'home-credit-default-risk/'

# %% [markdown]
# ## Part 1: Feature Engineering

# %%
df_app_train = pd.read_csv(data_path + 'application_train.csv')
df_app_test = pd.read_csv(data_path + 'application_test.csv')

# %%
## identify fill type based on feature meaning

to_fill_zero_cols = [
    'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'OWN_CAR_AGE', 'CNT_FAM_MEMBERS', 'DAYS_LAST_PHONE_CHANGE',
    ## How many observation of client's social surroundings
    'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE',
    ## Number of enquiries to Credit Bureau about the client
    'AMT_REQ_CREDIT_BUREAU_HOUR', 'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
    'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT', 'AMT_REQ_CREDIT_BUREAU_YEAR'
]

to_fill_avg_cols = [
    ## Normalized score from external data source
    'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3',
    ## Normalized information about building where the client lives
    'APARTMENTS_AVG', 'BASEMENTAREA_AVG',
    'YEARS_BEGINEXPLUATATION_AVG', 'YEARS_BUILD_AVG', 'COMMONAREA_AVG',
    'ELEVATORS_AVG', 'ENTRANCES_AVG', 'FLOORSMAX_AVG', 'FLOORSMIN_AVG',
    'LANDAREA_AVG', 'LIVINGAPARTMENTS_AVG', 'LIVINGAREA_AVG',
    'NONLIVINGAPARTMENTS_AVG', 'NONLIVINGAREA_AVG', 'APARTMENTS_MODE',
    'BASEMENTAREA_MODE', 'YEARS_BEGINEXPLUATATION_MODE', 'YEARS_BUILD_MODE',
    'COMMONAREA_MODE', 'ELEVATORS_MODE', 'ENTRANCES_MODE', 'FLOORSMAX_MODE',
    'FLOORSMIN_MODE', 'LANDAREA_MODE', 'LIVINGAPARTMENTS_MODE',
    'LIVINGAREA_MODE', 'NONLIVINGAPARTMENTS_MODE', 'NONLIVINGAREA_MODE',
    'APARTMENTS_MEDI', 'BASEMENTAREA_MEDI', 'YEARS_BEGINEXPLUATATION_MEDI',
    'YEARS_BUILD_MEDI', 'COMMONAREA_MEDI', 'ELEVATORS_MEDI',
    'ENTRANCES_MEDI', 'FLOORSMAX_MEDI', 'FLOORSMIN_MEDI', 'LANDAREA_MEDI',
    'LIVINGAPARTMENTS_MEDI', 'LIVINGAREA_MEDI', 'NONLIVINGAPARTMENTS_MEDI',
    'NONLIVINGAREA_MEDI', 'TOTALAREA_MODE'
]

# %%
def gen_feature_dummies(df_raw, to_fill_zero_cols, to_fill_avg_cols):
    df = pd.get_dummies(df_raw, dtype=int)
    df[to_fill_zero_cols] = df_app_train[to_fill_zero_cols].fillna(0)
    
    ## this method might be forward-looking bias for cross valiation, using for exploration only
    df[to_fill_avg_cols] = df_app_train[to_fill_avg_cols].fillna(df_app_train[to_fill_avg_cols].mean())
    df.columns = df.columns.str.upper().str.replace('[^A-Za-z0-9_]', '_', regex=True)
    return df

# %%
df_train = gen_feature_dummies(df_app_train, to_fill_zero_cols, to_fill_avg_cols)
df_test = gen_feature_dummies(df_app_test, to_fill_zero_cols, to_fill_avg_cols)

# %% [markdown]
# ## Part 2: Model Selection

# %%
def prepare_train_test_set(df_train, df_test):
    if 'SK_ID_CURR' in df_train.columns:
        X_train = df_train.drop(['SK_ID_CURR'], axis=1)
        X_test = df_test.drop(['SK_ID_CURR'], axis=1)
    else:
        X_train = df_train.copy()
        X_test = df_test.copy()
    y_train = df_app_train['TARGET']

    ## to handle missing dummy columns 
    to_add_cols = [c for c in X_train.columns if c not in X_test.columns]
    for c in to_add_cols:
        X_test[c] = 0
    X_test = X_test[X_train.columns]
    return X_train, y_train, X_test

def collect_model_result(oof_preds, auc_score, model_name):
    df_pred[model_name] = oof_preds
    dict_auc[model_name] = auc_score

# %%
df_pred = df_train[['TARGET']].copy()
dict_auc = dict()

# %% [markdown]
# ### 2.1) LogisticRegression

# %%
X_train, y_train, X_test = prepare_train_test_set(df_train.drop(['TARGET'], axis=1), df_test)
X_train.shape, X_test.shape
# Out:
# ((307511, 244), (48744, 244))

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score

folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
oof_preds = np.zeros(X_train.shape[0])
test_preds = np.zeros(X_test.shape[0])

for train_idx, val_idx in folds.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
    y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]
    
    model = make_pipeline(
        StandardScaler(), 
        LogisticRegression(max_iter=1000)
    )
    model.fit(X_tr, y_tr)

    oof_preds[val_idx] = model.predict_proba(X_val)[:, 1]
    test_preds += model.predict_proba(X_test)[:, 1] / folds.n_splits

print('CV AUC:', roc_auc_score(y_train, oof_preds))
# Out:
# CV AUC: 0.7467989136495174

# %%
collect_model_result(oof_preds, roc_auc_score(y_train, oof_preds), 'logisticregression')

# %%
coef = pd.Series(model.named_steps['logisticregression'].coef_[0], index=X_train.columns).sort_values(ascending=False)
coef
# Out:
# DAYS_EMPLOYED                               5.4955
# AMT_CREDIT                                  0.9682
# NAME_INCOME_TYPE_WORKING                    0.8490
# NAME_INCOME_TYPE_COMMERCIAL_ASSOCIATE       0.6809
# ORGANIZATION_TYPE_BUSINESS_ENTITY_TYPE_3    0.4677
#                                              ...
# EXT_SOURCE_2                               -0.3916
# EXT_SOURCE_3                               -0.4826
# AMT_GOODS_PRICE                            -1.0650
# ORGANIZATION_TYPE_XNA                      -2.0765
# NAME_INCOME_TYPE_PENSIONER                 -2.1200
# Length: 244, dtype: float64

# %%
selected_feature = coef[coef.abs() > 0.1].index
len(selected_feature)
# Out:
# 47

# %%
X_train, y_train, X_test = prepare_train_test_set(df_train[selected_feature], df_test[selected_feature])

folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
oof_preds = np.zeros(X_train.shape[0])
test_preds = np.zeros(X_test.shape[0])

for train_idx, val_idx in folds.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
    y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]
    
    model = make_pipeline(
        StandardScaler(), 
        LogisticRegression(max_iter=1000)
    )
    model.fit(X_tr, y_tr)

    oof_preds[val_idx] = model.predict_proba(X_val)[:, 1]
    test_preds += model.predict_proba(X_test)[:, 1] / folds.n_splits

print('CV AUC:', roc_auc_score(y_train, oof_preds))
# Out:
# CV AUC: 0.734724215515129

# %%
collect_model_result(oof_preds, roc_auc_score(y_train, oof_preds), 'logisticregression_top')

# %%
coef = pd.Series(model.named_steps['logisticregression'].coef_[0], index=X_train.columns).sort_values(ascending=False)
coef
# Out:
# DAYS_EMPLOYED                               6.2319
# FLAG_EMP_PHONE                              1.1220
# AMT_CREDIT                                  1.0260
# NAME_INCOME_TYPE_Working                    0.7257
# NAME_INCOME_TYPE_Commercial associate       0.5446
# YEARS_BUILD_AVG                             0.3140
# NAME_INCOME_TYPE_State servant              0.3070
# ENTRANCES_AVG                               0.2242
# BASEMENTAREA_MEDI                           0.1887
# AMT_ANNUITY                                 0.1476
# OBS_30_CNT_SOCIAL_CIRCLE                    0.1145
# FLAG_DOCUMENT_3                             0.1026
# ORGANIZATION_TYPE_Self-employed             0.0959
# ORGANIZATION_TYPE_Business Entity Type 3    0.0858
# REGION_RATING_CLIENT_W_CITY                 0.0741
# LIVINGAPARTMENTS_MEDI                       0.0642
# ORGANIZATION_TYPE_Construction              0.0620
# ORGANIZATION_TYPE_Transport: type 3         0.0517
# NAME_TYPE_SUITE_Unaccompanied               0.0375
# ORGANIZATION_TYPE_Business Entity Type 2    0.0327
# ORGANIZATION_TYPE_Trade: type 7             0.0302
# ELEVATORS_MODE                              0.0274
# ORGANIZATION_TYPE_Transport: type 4         0.0273
# ORGANIZATION_TYPE_Industry: type 3          0.0269
# ORGANIZATION_TYPE_Other                     0.0265
# ORGANIZATION_TYPE_Trade: type 3             0.0261
# ORGANIZATION_TYPE_Housing                   0.0187
# NAME_TYPE_SUITE_Family                      0.0184
# NAME_TYPE_SUITE_Spouse, partner             0.0165
# ORGANIZATION_TYPE_Business Entity Type 1    0.0160
# ORGANIZATION_TYPE_Government                0.0010
# ORGANIZATION_TYPE_Medicine                 -0.0041
# ORGANIZATION_TYPE_Kindergarten             -0.0083
# COMMONAREA_MEDI                            -0.0122
# ORGANIZATION_TYPE_School                   -0.0219
# LIVINGAPARTMENTS_AVG                       -0.0387
# ELEVATORS_AVG                              -0.0490
# OBS_60_CNT_SOCIAL_CIRCLE                   -0.0923
# BASEMENTAREA_AVG                           -0.1932
# EXT_SOURCE_1                               -0.1974
# ENTRANCES_MEDI                             -0.2506
# YEARS_BUILD_MEDI                           -0.3531
# EXT_SOURCE_2                               -0.4327
# EXT_SOURCE_3                               -0.4708
# NAME_INCOME_TYPE_Pensioner                 -1.1110
# AMT_GOODS_PRICE                            -1.1824
# ORGANIZATION_TYPE_XNA                      -3.4896
# dtype: float64

# %% [markdown]
# ### 2.2) XGBClassifier

# %%
X_train, y_train, X_test = prepare_train_test_set(df_train.drop(['TARGET'], axis=1), df_test)
X_train.shape, X_test.shape
# Out:
# ((307511, 244), (48744, 244))

# %%
from xgboost import XGBClassifier

folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
oof_preds = np.zeros(X_train.shape[0])
test_preds = np.zeros(X_test.shape[0])

for train_idx, val_idx in folds.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
    y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]

    model = XGBClassifier(eval_metric=roc_auc_score, random_state=123)
    model.fit(X_tr, y_tr, eval_set=[(X_val, y_val)])

    oof_preds[val_idx] = model.predict_proba(X_val)[:, 1]
    test_preds += model.predict_proba(X_test)[:, 1] / folds.n_splits

print('CV AUC:', roc_auc_score(y_train, oof_preds))
# Out:
# [0]	validation_0-logloss:0.28725	validation_0-roc_auc_score:0.70859
# [1]	validation_0-logloss:0.27489	validation_0-roc_auc_score:0.71850
# [2]	validation_0-logloss:0.26710	validation_0-roc_auc_score:0.72305
# [3]	validation_0-logloss:0.26196	validation_0-roc_auc_score:0.72566
# [4]	validation_0-logloss:0.25857	validation_0-roc_auc_score:0.72824
# [5]	validation_0-logloss:0.25632	validation_0-roc_auc_score:0.73002
# [6]	validation_0-logloss:0.25450	validation_0-roc_auc_score:0.73393
# [7]	validation_0-logloss:0.25354	validation_0-roc_auc_score:0.73488
# [8]	validation_0-logloss:0.25266	validation_0-roc_auc_score:0.73753
# [9]	validation_0-logloss:0.25198	validation_0-roc_auc_score:0.73961
# [10]	validation_0-logloss:0.25133	validation_0-roc_auc_score:0.74135
# [11]	validation_0-logloss:0.25084	validation_0-roc_auc_score:0.74262
# [12]	validation_0-logloss:0.25050	validation_0-roc_auc_score:0.74347
# [13]	validation_0-logloss:0.25015	validation_0-roc_auc_score:0.74474
# [14]	validation_0-logloss:0.25001	validation_0-roc_auc_score:0.74511
# [15]	validation_0-logloss:0.24986	validation_0-roc_auc_score:0.74549
# [16]	validation_0-logloss:0.24969	validation_0-roc_auc_score:0.74599
# [17]	validation_0-logloss:0.24964	validation_0-roc_auc_score:0.74611
# [18]	validation_0-logloss:0.24953	validation_0-roc_auc_score:0.74663
# [19]	validation_0-logloss:0.24932	validation_0-roc_auc_score:0.74754
# [20]	validation_0-logloss:0.24923	validation_0-roc_auc_score:0.74804
# [21]	validation_0-logloss:0.24906	validation_0-roc_auc_score:0.74867
# [22]	validation_0-logloss:0.24895	validation_0-roc_auc_score:0.74915
# [23]	validation_0-logloss:0.24886	validation_0-roc_auc_score:0.74950
# [24]	validation_0-logloss:0.24885	validation_0-roc_auc_score:0.74957
# [25]	validation_0-logloss:0.24892	validation_0-roc_auc_score:0.74920
# [26]	validation_0-logloss:0.24886	validation_0-roc_auc_score:0.74924
# [27]	validation_0-logloss:0.24878	validation_0-roc_auc_score:0.74946
# [28]	validation_0-logloss:0.24846	validation_0-roc_auc_score:0.75058
# [29]	validation_0-logloss:0.24849	validation_0-roc_auc_score:0.75034
# [30]	validation_0-logloss:0.24845	validation_0-roc_auc_score:0.75059
# [31]	validation_0-logloss:0.24847	validation_0-roc_auc_score:0.75068
# [32]	validation_0-logloss:0.24840	validation_0-roc_auc_score:0.75097
# [33]	validation_0-logloss:0.24838	validation_0-roc_auc_score:0.75099
# [34]	validation_0-logloss:0.24839	validation_0-roc_auc_score:0.75095
# [35]	validation_0-logloss:0.24839	validation_0-roc_auc_score:0.75101
# [36]	validation_0-logloss:0.24834	validation_0-roc_auc_score:0.75110
# [37]	validation_0-logloss:0.24842	validation_0-roc_auc_score:0.75090
# [38]	validation_0-logloss:0.24841	validation_0-roc_auc_score:0.75112
# [39]	validation_0-logloss:0.24842	validation_0-roc_auc_score:0.75105
# [40]	validation_0-logloss:0.24841	validation_0-roc_auc_score:0.75108
# [41]	validation_0-logloss:0.24840	validation_0-roc_auc_score:0.75127
# [42]	validation_0-logloss:0.24840	validation_0-roc_auc_score:0.75122
# [43]	validation_0-logloss:0.24838	validation_0-roc_auc_score:0.75117
# [44]	validation_0-logloss:0.24836	validation_0-roc_auc_score:0.75129
# [45]	validation_0-logloss:0.24840	validation_0-roc_auc_score:0.75109
# [46]	validation_0-logloss:0.24852	validation_0-roc_auc_score:0.75074
# [47]	validation_0-logloss:0.24857	validation_0-roc_auc_score:0.75063
# [48]	validation_0-logloss:0.24852	validation_0-roc_auc_score:0.75084
# [49]	validation_0-logloss:0.24857	validation_0-roc_auc_score:0.75061
# [50]	validation_0-logloss:0.24856	validation_0-roc_auc_score:0.75055
# [51]	validation_0-logloss:0.24856	validation_0-roc_auc_score:0.75061
# [52]	validation_0-logloss:0.24856	validation_0-roc_auc_score:0.75068
# [53]	validation_0-logloss:0.24863	validation_0-roc_auc_score:0.75051
# [54]	validation_0-logloss:0.24861	validation_0-roc_auc_score:0.75065
# [55]	validation_0-logloss:0.24863	validation_0-roc_auc_score:0.75050
# [56]	validation_0-logloss:0.24871	validation_0-roc_auc_score:0.75043
# [57]	validation_0-logloss:0.24875	validation_0-roc_auc_score:0.75026
# [58]	validation_0-logloss:0.24880	validation_0-roc_auc_score:0.75013
# [59]	validation_0-logloss:0.24883	validation_0-roc_auc_score:0.75009
# [60]	validation_0-logloss:0.24883	validation_0-roc_auc_score:0.75011
# [61]	validation_0-logloss:0.24881	validation_0-roc_auc_score:0.75016
# [62]	validation_0-logloss:0.24880	validation_0-roc_auc_score:0.75027
# [63]	validation_0-logloss:0.24885	validation_0-roc_auc_score:0.75014
# [64]	validation_0-logloss:0.24882	validation_0-roc_auc_score:0.75022
# [65]	validation_0-logloss:0.24878	validation_0-roc_auc_score:0.75038
# [66]	validation_0-logloss:0.24882	validation_0-roc_auc_score:0.75043
# [67]	validation_0-logloss:0.24885	validation_0-roc_auc_score:0.75039
# [68]	validation_0-logloss:0.24881	validation_0-roc_auc_score:0.75059
# [69]	validation_0-logloss:0.24888	validation_0-roc_auc_score:0.75042
# [70]	validation_0-logloss:0.24889	validation_0-roc_auc_score:0.75033
# [71]	validation_0-logloss:0.24892	validation_0-roc_auc_score:0.75025
# [72]	validation_0-logloss:0.24901	validation_0-roc_auc_score:0.74985
# [73]	validation_0-logloss:0.24906	validation_0-roc_auc_score:0.74964
# [74]	validation_0-logloss:0.24914	validation_0-roc_auc_score:0.74935
# [75]	validation_0-logloss:0.24919	validation_0-roc_auc_score:0.74923
# [76]	validation_0-logloss:0.24923	validation_0-roc_auc_score:0.74915
# [77]	validation_0-logloss:0.24924	validation_0-roc_auc_score:0.74913
# [78]	validation_0-logloss:0.24927	validation_0-roc_auc_score:0.74903
# [79]	validation_0-logloss:0.24927	validation_0-roc_auc_score:0.74902
# [80]	validation_0-logloss:0.24932	validation_0-roc_auc_score:0.74886
# [81]	validation_0-logloss:0.24936	validation_0-roc_auc_score:0.74868
# [82]	validation_0-logloss:0.24941	validation_0-roc_auc_score:0.74855
# [83]	validation_0-logloss:0.24947	validation_0-roc_auc_score:0.74845
# [84]	validation_0-logloss:0.24949	validation_0-roc_auc_score:0.74838
# [85]	validation_0-logloss:0.24955	validation_0-roc_auc_score:0.74823
# [86]	validation_0-logloss:0.24961	validation_0-roc_auc_score:0.74816
# [87]	validation_0-logloss:0.24966	validation_0-roc_auc_score:0.74809
# [88]	validation_0-logloss:0.24961	validation_0-roc_auc_score:0.74822
# [89]	validation_0-logloss:0.24961	validation_0-roc_auc_score:0.74822
# [90]	validation_0-logloss:0.24965	validation_0-roc_auc_score:0.74811
# [91]	validation_0-logloss:0.24965	validation_0-roc_auc_score:0.74811
# [92]	validation_0-logloss:0.24968	validation_0-roc_auc_score:0.74799
# [93]	validation_0-logloss:0.24970	validation_0-roc_auc_score:0.74790
# [94]	validation_0-logloss:0.24970	validation_0-roc_auc_score:0.74796
# [95]	validation_0-logloss:0.24972	validation_0-roc_auc_score:0.74802
# [96]	validation_0-logloss:0.24980	validation_0-roc_auc_score:0.74765
# [97]	validation_0-logloss:0.24985	validation_0-roc_auc_score:0.74750
# [98]	validation_0-logloss:0.24992	validation_0-roc_auc_score:0.74709
# [99]	validation_0-logloss:0.24994	validation_0-roc_auc_score:0.74712
# [0]	validation_0-logloss:0.28713	validation_0-roc_auc_score:0.71150
# [1]	validation_0-logloss:0.27497	validation_0-roc_auc_score:0.71870
# [2]	validation_0-logloss:0.26721	validation_0-roc_auc_score:0.72079
# [3]	validation_0-logloss:0.26184	validation_0-roc_auc_score:0.72638
# [4]	validation_0-logloss:0.25849	validation_0-roc_auc_score:0.72905
# [5]	validation_0-logloss:0.25623	validation_0-roc_auc_score:0.73074
# [6]	validation_0-logloss:0.25443	validation_0-roc_auc_score:0.73415
# [7]	validation_0-logloss:0.25295	validation_0-roc_auc_score:0.73784
# [8]	validation_0-logloss:0.25206	validation_0-roc_auc_score:0.73960
# [9]	validation_0-logloss:0.25118	validation_0-roc_auc_score:0.74221
# [10]	validation_0-logloss:0.25059	validation_0-roc_auc_score:0.74361
# [11]	validation_0-logloss:0.25017	validation_0-roc_auc_score:0.74447
# [12]	validation_0-logloss:0.24975	validation_0-roc_auc_score:0.74582
# [13]	validation_0-logloss:0.24915	validation_0-roc_auc_score:0.74764
# [14]	validation_0-logloss:0.24878	validation_0-roc_auc_score:0.74878
# [15]	validation_0-logloss:0.24864	validation_0-roc_auc_score:0.74920
# [16]	validation_0-logloss:0.24862	validation_0-roc_auc_score:0.74907
# [17]	validation_0-logloss:0.24849	validation_0-roc_auc_score:0.74943
# [18]	validation_0-logloss:0.24826	validation_0-roc_auc_score:0.75024
# [19]	validation_0-logloss:0.24808	validation_0-roc_auc_score:0.75074
# [20]	validation_0-logloss:0.24803	validation_0-roc_auc_score:0.75094
# [21]	validation_0-logloss:0.24800	validation_0-roc_auc_score:0.75103
# [22]	validation_0-logloss:0.24795	validation_0-roc_auc_score:0.75103
# [23]	validation_0-logloss:0.24784	validation_0-roc_auc_score:0.75145
# [24]	validation_0-logloss:0.24769	validation_0-roc_auc_score:0.75189
# [25]	validation_0-logloss:0.24753	validation_0-roc_auc_score:0.75234
# [26]	validation_0-logloss:0.24750	validation_0-roc_auc_score:0.75237
# [27]	validation_0-logloss:0.24754	validation_0-roc_auc_score:0.75225
# [28]	validation_0-logloss:0.24746	validation_0-roc_auc_score:0.75262
# [29]	validation_0-logloss:0.24748	validation_0-roc_auc_score:0.75251
# [30]	validation_0-logloss:0.24746	validation_0-roc_auc_score:0.75269
# [31]	validation_0-logloss:0.24742	validation_0-roc_auc_score:0.75280
# [32]	validation_0-logloss:0.24733	validation_0-roc_auc_score:0.75310
# [33]	validation_0-logloss:0.24729	validation_0-roc_auc_score:0.75319
# [34]	validation_0-logloss:0.24726	validation_0-roc_auc_score:0.75328
# [35]	validation_0-logloss:0.24730	validation_0-roc_auc_score:0.75323
# [36]	validation_0-logloss:0.24726	validation_0-roc_auc_score:0.75340
# [37]	validation_0-logloss:0.24730	validation_0-roc_auc_score:0.75325
# [38]	validation_0-logloss:0.24738	validation_0-roc_auc_score:0.75295
# [39]	validation_0-logloss:0.24742	validation_0-roc_auc_score:0.75284
# [40]	validation_0-logloss:0.24738	validation_0-roc_auc_score:0.75299
# [41]	validation_0-logloss:0.24743	validation_0-roc_auc_score:0.75283
# [42]	validation_0-logloss:0.24748	validation_0-roc_auc_score:0.75258
# [43]	validation_0-logloss:0.24756	validation_0-roc_auc_score:0.75228
# [44]	validation_0-logloss:0.24758	validation_0-roc_auc_score:0.75231
# [45]	validation_0-logloss:0.24757	validation_0-roc_auc_score:0.75231
# [46]	validation_0-logloss:0.24759	validation_0-roc_auc_score:0.75225
# [47]	validation_0-logloss:0.24770	validation_0-roc_auc_score:0.75195
# [48]	validation_0-logloss:0.24773	validation_0-roc_auc_score:0.75198
# [49]	validation_0-logloss:0.24769	validation_0-roc_auc_score:0.75210
# [50]	validation_0-logloss:0.24766	validation_0-roc_auc_score:0.75224
# [51]	validation_0-logloss:0.24768	validation_0-roc_auc_score:0.75218
# [52]	validation_0-logloss:0.24772	validation_0-roc_auc_score:0.75194
# [53]	validation_0-logloss:0.24770	validation_0-roc_auc_score:0.75201
# [54]	validation_0-logloss:0.24769	validation_0-roc_auc_score:0.75211
# [55]	validation_0-logloss:0.24778	validation_0-roc_auc_score:0.75174
# [56]	validation_0-logloss:0.24775	validation_0-roc_auc_score:0.75185
# [57]	validation_0-logloss:0.24781	validation_0-roc_auc_score:0.75171
# [58]	validation_0-logloss:0.24781	validation_0-roc_auc_score:0.75184
# [59]	validation_0-logloss:0.24783	validation_0-roc_auc_score:0.75192
# [60]	validation_0-logloss:0.24785	validation_0-roc_auc_score:0.75196
# [61]	validation_0-logloss:0.24784	validation_0-roc_auc_score:0.75202
# [62]	validation_0-logloss:0.24785	validation_0-roc_auc_score:0.75207
# [63]	validation_0-logloss:0.24786	validation_0-roc_auc_score:0.75209
# [64]	validation_0-logloss:0.24788	validation_0-roc_auc_score:0.75206
# [65]	validation_0-logloss:0.24787	validation_0-roc_auc_score:0.75205
# [66]	validation_0-logloss:0.24789	validation_0-roc_auc_score:0.75199
# [67]	validation_0-logloss:0.24787	validation_0-roc_auc_score:0.75203
# [68]	validation_0-logloss:0.24788	validation_0-roc_auc_score:0.75197
# [69]	validation_0-logloss:0.24790	validation_0-roc_auc_score:0.75182
# [70]	validation_0-logloss:0.24793	validation_0-roc_auc_score:0.75175
# [71]	validation_0-logloss:0.24785	validation_0-roc_auc_score:0.75200
# [72]	validation_0-logloss:0.24784	validation_0-roc_auc_score:0.75199
# [73]	validation_0-logloss:0.24789	validation_0-roc_auc_score:0.75192
# [74]	validation_0-logloss:0.24788	validation_0-roc_auc_score:0.75194
# [75]	validation_0-logloss:0.24795	validation_0-roc_auc_score:0.75180
# [76]	validation_0-logloss:0.24791	validation_0-roc_auc_score:0.75195
# [77]	validation_0-logloss:0.24795	validation_0-roc_auc_score:0.75171
# [78]	validation_0-logloss:0.24798	validation_0-roc_auc_score:0.75156
# [79]	validation_0-logloss:0.24799	validation_0-roc_auc_score:0.75159
# [80]	validation_0-logloss:0.24801	validation_0-roc_auc_score:0.75155
# [81]	validation_0-logloss:0.24807	validation_0-roc_auc_score:0.75137
# [82]	validation_0-logloss:0.24816	validation_0-roc_auc_score:0.75103
# [83]	validation_0-logloss:0.24815	validation_0-roc_auc_score:0.75104
# [84]	validation_0-logloss:0.24816	validation_0-roc_auc_score:0.75097
# [85]	validation_0-logloss:0.24814	validation_0-roc_auc_score:0.75096
# [86]	validation_0-logloss:0.24817	validation_0-roc_auc_score:0.75092
# [87]	validation_0-logloss:0.24821	validation_0-roc_auc_score:0.75087
# [88]	validation_0-logloss:0.24822	validation_0-roc_auc_score:0.75089
# [89]	validation_0-logloss:0.24826	validation_0-roc_auc_score:0.75076
# [90]	validation_0-logloss:0.24829	validation_0-roc_auc_score:0.75060
# [91]	validation_0-logloss:0.24835	validation_0-roc_auc_score:0.75043
# [92]	validation_0-logloss:0.24843	validation_0-roc_auc_score:0.75024
# [93]	validation_0-logloss:0.24847	validation_0-roc_auc_score:0.75021
# [94]	validation_0-logloss:0.24857	validation_0-roc_auc_score:0.74988
# [95]	validation_0-logloss:0.24859	validation_0-roc_auc_score:0.74985
# [96]	validation_0-logloss:0.24858	validation_0-roc_auc_score:0.74988
# [97]	validation_0-logloss:0.24859	validation_0-roc_auc_score:0.74984
# [98]	validation_0-logloss:0.24860	validation_0-roc_auc_score:0.74978
# [99]	validation_0-logloss:0.24860	validation_0-roc_auc_score:0.74983
# [0]	validation_0-logloss:0.28681	validation_0-roc_auc_score:0.71970
# [1]	validation_0-logloss:0.27444	validation_0-roc_auc_score:0.72621
# [2]	validation_0-logloss:0.26645	validation_0-roc_auc_score:0.73137
# [3]	validation_0-logloss:0.26118	validation_0-roc_auc_score:0.73447
# [4]	validation_0-logloss:0.25741	validation_0-roc_auc_score:0.73872
# [5]	validation_0-logloss:0.25503	validation_0-roc_auc_score:0.74029
# [6]	validation_0-logloss:0.25325	validation_0-roc_auc_score:0.74292
# [7]	validation_0-logloss:0.25194	validation_0-roc_auc_score:0.74508
# [8]	validation_0-logloss:0.25096	validation_0-roc_auc_score:0.74645
# [9]	validation_0-logloss:0.25002	validation_0-roc_auc_score:0.74835
# [10]	validation_0-logloss:0.24955	validation_0-roc_auc_score:0.74944
# [11]	validation_0-logloss:0.24920	validation_0-roc_auc_score:0.74989
# [12]	validation_0-logloss:0.24882	validation_0-roc_auc_score:0.75061
# [13]	validation_0-logloss:0.24845	validation_0-roc_auc_score:0.75183
# [14]	validation_0-logloss:0.24812	validation_0-roc_auc_score:0.75242
# [15]	validation_0-logloss:0.24778	validation_0-roc_auc_score:0.75343
# [16]	validation_0-logloss:0.24769	validation_0-roc_auc_score:0.75346
# [17]	validation_0-logloss:0.24756	validation_0-roc_auc_score:0.75360
# [18]	validation_0-logloss:0.24750	validation_0-roc_auc_score:0.75379
# [19]	validation_0-logloss:0.24726	validation_0-roc_auc_score:0.75471
# [20]	validation_0-logloss:0.24721	validation_0-roc_auc_score:0.75487
# [21]	validation_0-logloss:0.24709	validation_0-roc_auc_score:0.75524
# [22]	validation_0-logloss:0.24700	validation_0-roc_auc_score:0.75540
# [23]	validation_0-logloss:0.24701	validation_0-roc_auc_score:0.75540
# [24]	validation_0-logloss:0.24692	validation_0-roc_auc_score:0.75562
# [25]	validation_0-logloss:0.24691	validation_0-roc_auc_score:0.75565
# [26]	validation_0-logloss:0.24690	validation_0-roc_auc_score:0.75578
# [27]	validation_0-logloss:0.24689	validation_0-roc_auc_score:0.75589
# [28]	validation_0-logloss:0.24684	validation_0-roc_auc_score:0.75599
# [29]	validation_0-logloss:0.24694	validation_0-roc_auc_score:0.75572
# [30]	validation_0-logloss:0.24673	validation_0-roc_auc_score:0.75658
# [31]	validation_0-logloss:0.24674	validation_0-roc_auc_score:0.75659
# [32]	validation_0-logloss:0.24681	validation_0-roc_auc_score:0.75628
# [33]	validation_0-logloss:0.24691	validation_0-roc_auc_score:0.75583
# [34]	validation_0-logloss:0.24690	validation_0-roc_auc_score:0.75589
# [35]	validation_0-logloss:0.24689	validation_0-roc_auc_score:0.75602
# [36]	validation_0-logloss:0.24692	validation_0-roc_auc_score:0.75606
# [37]	validation_0-logloss:0.24690	validation_0-roc_auc_score:0.75612
# [38]	validation_0-logloss:0.24688	validation_0-roc_auc_score:0.75616
# [39]	validation_0-logloss:0.24693	validation_0-roc_auc_score:0.75606
# [40]	validation_0-logloss:0.24690	validation_0-roc_auc_score:0.75608
# [41]	validation_0-logloss:0.24691	validation_0-roc_auc_score:0.75607
# [42]	validation_0-logloss:0.24679	validation_0-roc_auc_score:0.75662
# [43]	validation_0-logloss:0.24677	validation_0-roc_auc_score:0.75662
# [44]	validation_0-logloss:0.24680	validation_0-roc_auc_score:0.75676
# [45]	validation_0-logloss:0.24679	validation_0-roc_auc_score:0.75685
# [46]	validation_0-logloss:0.24674	validation_0-roc_auc_score:0.75697
# [47]	validation_0-logloss:0.24681	validation_0-roc_auc_score:0.75668
# [48]	validation_0-logloss:0.24691	validation_0-roc_auc_score:0.75631
# [49]	validation_0-logloss:0.24678	validation_0-roc_auc_score:0.75681
# [50]	validation_0-logloss:0.24677	validation_0-roc_auc_score:0.75686
# [51]	validation_0-logloss:0.24681	validation_0-roc_auc_score:0.75677
# [52]	validation_0-logloss:0.24684	validation_0-roc_auc_score:0.75666
# [53]	validation_0-logloss:0.24694	validation_0-roc_auc_score:0.75626
# [54]	validation_0-logloss:0.24693	validation_0-roc_auc_score:0.75631
# [55]	validation_0-logloss:0.24694	validation_0-roc_auc_score:0.75635
# [56]	validation_0-logloss:0.24690	validation_0-roc_auc_score:0.75644
# [57]	validation_0-logloss:0.24689	validation_0-roc_auc_score:0.75649
# [58]	validation_0-logloss:0.24694	validation_0-roc_auc_score:0.75623
# [59]	validation_0-logloss:0.24698	validation_0-roc_auc_score:0.75604
# [60]	validation_0-logloss:0.24701	validation_0-roc_auc_score:0.75609
# [61]	validation_0-logloss:0.24700	validation_0-roc_auc_score:0.75620
# [62]	validation_0-logloss:0.24702	validation_0-roc_auc_score:0.75606
# [63]	validation_0-logloss:0.24703	validation_0-roc_auc_score:0.75609
# [64]	validation_0-logloss:0.24706	validation_0-roc_auc_score:0.75599
# [65]	validation_0-logloss:0.24707	validation_0-roc_auc_score:0.75600
# [66]	validation_0-logloss:0.24712	validation_0-roc_auc_score:0.75583
# [67]	validation_0-logloss:0.24715	validation_0-roc_auc_score:0.75573
# [68]	validation_0-logloss:0.24720	validation_0-roc_auc_score:0.75560
# [69]	validation_0-logloss:0.24729	validation_0-roc_auc_score:0.75523
# [70]	validation_0-logloss:0.24726	validation_0-roc_auc_score:0.75529
# [71]	validation_0-logloss:0.24731	validation_0-roc_auc_score:0.75508
# [72]	validation_0-logloss:0.24735	validation_0-roc_auc_score:0.75496
# [73]	validation_0-logloss:0.24738	validation_0-roc_auc_score:0.75499
# [74]	validation_0-logloss:0.24737	validation_0-roc_auc_score:0.75504
# [75]	validation_0-logloss:0.24734	validation_0-roc_auc_score:0.75520
# [76]	validation_0-logloss:0.24736	validation_0-roc_auc_score:0.75521
# [77]	validation_0-logloss:0.24746	validation_0-roc_auc_score:0.75502
# [78]	validation_0-logloss:0.24743	validation_0-roc_auc_score:0.75514
# [79]	validation_0-logloss:0.24749	validation_0-roc_auc_score:0.75489
# [80]	validation_0-logloss:0.24754	validation_0-roc_auc_score:0.75474
# [81]	validation_0-logloss:0.24757	validation_0-roc_auc_score:0.75461
# [82]	validation_0-logloss:0.24763	validation_0-roc_auc_score:0.75437
# [83]	validation_0-logloss:0.24766	validation_0-roc_auc_score:0.75429
# [84]	validation_0-logloss:0.24767	validation_0-roc_auc_score:0.75431
# [85]	validation_0-logloss:0.24765	validation_0-roc_auc_score:0.75441
# [86]	validation_0-logloss:0.24758	validation_0-roc_auc_score:0.75460
# [87]	validation_0-logloss:0.24760	validation_0-roc_auc_score:0.75443
# [88]	validation_0-logloss:0.24756	validation_0-roc_auc_score:0.75460
# [89]	validation_0-logloss:0.24765	validation_0-roc_auc_score:0.75435
# [90]	validation_0-logloss:0.24769	validation_0-roc_auc_score:0.75425
# [91]	validation_0-logloss:0.24771	validation_0-roc_auc_score:0.75424
# [92]	validation_0-logloss:0.24779	validation_0-roc_auc_score:0.75407
# [93]	validation_0-logloss:0.24785	validation_0-roc_auc_score:0.75389
# [94]	validation_0-logloss:0.24783	validation_0-roc_auc_score:0.75401
# [95]	validation_0-logloss:0.24783	validation_0-roc_auc_score:0.75406
# [96]	validation_0-logloss:0.24787	validation_0-roc_auc_score:0.75399
# [97]	validation_0-logloss:0.24791	validation_0-roc_auc_score:0.75382
# [98]	validation_0-logloss:0.24793	validation_0-roc_auc_score:0.75385
# [99]	validation_0-logloss:0.24794	validation_0-roc_auc_score:0.75388
# [0]	validation_0-logloss:0.28720	validation_0-roc_auc_score:0.70889
# [1]	validation_0-logloss:0.27510	validation_0-roc_auc_score:0.71588
# [2]	validation_0-logloss:0.26735	validation_0-roc_auc_score:0.72096
# [3]	validation_0-logloss:0.26214	validation_0-roc_auc_score:0.72615
# [4]	validation_0-logloss:0.25872	validation_0-roc_auc_score:0.72847
# [5]	validation_0-logloss:0.25632	validation_0-roc_auc_score:0.73205
# [6]	validation_0-logloss:0.25472	validation_0-roc_auc_score:0.73420
# [7]	validation_0-logloss:0.25361	validation_0-roc_auc_score:0.73671
# [8]	validation_0-logloss:0.25266	validation_0-roc_auc_score:0.73833
# [9]	validation_0-logloss:0.25202	validation_0-roc_auc_score:0.73967
# [10]	validation_0-logloss:0.25132	validation_0-roc_auc_score:0.74197
# [11]	validation_0-logloss:0.25110	validation_0-roc_auc_score:0.74244
# [12]	validation_0-logloss:0.25051	validation_0-roc_auc_score:0.74437
# [13]	validation_0-logloss:0.25009	validation_0-roc_auc_score:0.74540
# [14]	validation_0-logloss:0.24970	validation_0-roc_auc_score:0.74690
# [15]	validation_0-logloss:0.24949	validation_0-roc_auc_score:0.74753
# [16]	validation_0-logloss:0.24922	validation_0-roc_auc_score:0.74843
# [17]	validation_0-logloss:0.24920	validation_0-roc_auc_score:0.74858
# [18]	validation_0-logloss:0.24921	validation_0-roc_auc_score:0.74854
# [19]	validation_0-logloss:0.24906	validation_0-roc_auc_score:0.74922
# [20]	validation_0-logloss:0.24901	validation_0-roc_auc_score:0.74937
# [21]	validation_0-logloss:0.24898	validation_0-roc_auc_score:0.74946
# [22]	validation_0-logloss:0.24893	validation_0-roc_auc_score:0.74959
# [23]	validation_0-logloss:0.24896	validation_0-roc_auc_score:0.74964
# [24]	validation_0-logloss:0.24891	validation_0-roc_auc_score:0.74986
# [25]	validation_0-logloss:0.24885	validation_0-roc_auc_score:0.74995
# [26]	validation_0-logloss:0.24881	validation_0-roc_auc_score:0.74999
# [27]	validation_0-logloss:0.24874	validation_0-roc_auc_score:0.75024
# [28]	validation_0-logloss:0.24868	validation_0-roc_auc_score:0.75048
# [29]	validation_0-logloss:0.24871	validation_0-roc_auc_score:0.75043
# [30]	validation_0-logloss:0.24879	validation_0-roc_auc_score:0.75040
# [31]	validation_0-logloss:0.24890	validation_0-roc_auc_score:0.75020
# [32]	validation_0-logloss:0.24888	validation_0-roc_auc_score:0.75060
# [33]	validation_0-logloss:0.24890	validation_0-roc_auc_score:0.75076
# [34]	validation_0-logloss:0.24894	validation_0-roc_auc_score:0.75064
# [35]	validation_0-logloss:0.24887	validation_0-roc_auc_score:0.75112
# [36]	validation_0-logloss:0.24860	validation_0-roc_auc_score:0.75232
# [37]	validation_0-logloss:0.24861	validation_0-roc_auc_score:0.75236
# [38]	validation_0-logloss:0.24869	validation_0-roc_auc_score:0.75201
# [39]	validation_0-logloss:0.24873	validation_0-roc_auc_score:0.75191
# [40]	validation_0-logloss:0.24875	validation_0-roc_auc_score:0.75184
# [41]	validation_0-logloss:0.24871	validation_0-roc_auc_score:0.75203
# [42]	validation_0-logloss:0.24857	validation_0-roc_auc_score:0.75251
# [43]	validation_0-logloss:0.24859	validation_0-roc_auc_score:0.75247
# [44]	validation_0-logloss:0.24859	validation_0-roc_auc_score:0.75249
# [45]	validation_0-logloss:0.24856	validation_0-roc_auc_score:0.75260
# [46]	validation_0-logloss:0.24857	validation_0-roc_auc_score:0.75269
# [47]	validation_0-logloss:0.24858	validation_0-roc_auc_score:0.75272
# [48]	validation_0-logloss:0.24853	validation_0-roc_auc_score:0.75289
# [49]	validation_0-logloss:0.24857	validation_0-roc_auc_score:0.75282
# [50]	validation_0-logloss:0.24866	validation_0-roc_auc_score:0.75251
# [51]	validation_0-logloss:0.24873	validation_0-roc_auc_score:0.75233
# [52]	validation_0-logloss:0.24872	validation_0-roc_auc_score:0.75231
# [53]	validation_0-logloss:0.24878	validation_0-roc_auc_score:0.75227
# [54]	validation_0-logloss:0.24872	validation_0-roc_auc_score:0.75253
# [55]	validation_0-logloss:0.24868	validation_0-roc_auc_score:0.75274
# [56]	validation_0-logloss:0.24869	validation_0-roc_auc_score:0.75272
# [57]	validation_0-logloss:0.24870	validation_0-roc_auc_score:0.75276
# [58]	validation_0-logloss:0.24874	validation_0-roc_auc_score:0.75265
# [59]	validation_0-logloss:0.24878	validation_0-roc_auc_score:0.75269
# [60]	validation_0-logloss:0.24884	validation_0-roc_auc_score:0.75251
# [61]	validation_0-logloss:0.24890	validation_0-roc_auc_score:0.75244
# [62]	validation_0-logloss:0.24897	validation_0-roc_auc_score:0.75227
# [63]	validation_0-logloss:0.24906	validation_0-roc_auc_score:0.75203
# [64]	validation_0-logloss:0.24906	validation_0-roc_auc_score:0.75195
# [65]	validation_0-logloss:0.24906	validation_0-roc_auc_score:0.75196
# [66]	validation_0-logloss:0.24910	validation_0-roc_auc_score:0.75185
# [67]	validation_0-logloss:0.24909	validation_0-roc_auc_score:0.75192
# [68]	validation_0-logloss:0.24907	validation_0-roc_auc_score:0.75185
# [69]	validation_0-logloss:0.24905	validation_0-roc_auc_score:0.75199
# [70]	validation_0-logloss:0.24914	validation_0-roc_auc_score:0.75167
# [71]	validation_0-logloss:0.24917	validation_0-roc_auc_score:0.75167
# [72]	validation_0-logloss:0.24923	validation_0-roc_auc_score:0.75167
# [73]	validation_0-logloss:0.24929	validation_0-roc_auc_score:0.75144
# [74]	validation_0-logloss:0.24929	validation_0-roc_auc_score:0.75153
# [75]	validation_0-logloss:0.24930	validation_0-roc_auc_score:0.75150
# [76]	validation_0-logloss:0.24935	validation_0-roc_auc_score:0.75145
# [77]	validation_0-logloss:0.24948	validation_0-roc_auc_score:0.75108
# [78]	validation_0-logloss:0.24950	validation_0-roc_auc_score:0.75111
# [79]	validation_0-logloss:0.24947	validation_0-roc_auc_score:0.75115
# [80]	validation_0-logloss:0.24946	validation_0-roc_auc_score:0.75114
# [81]	validation_0-logloss:0.24948	validation_0-roc_auc_score:0.75113
# [82]	validation_0-logloss:0.24953	validation_0-roc_auc_score:0.75100
# [83]	validation_0-logloss:0.24955	validation_0-roc_auc_score:0.75086
# [84]	validation_0-logloss:0.24961	validation_0-roc_auc_score:0.75079
# [85]	validation_0-logloss:0.24968	validation_0-roc_auc_score:0.75059
# [86]	validation_0-logloss:0.24967	validation_0-roc_auc_score:0.75072
# [87]	validation_0-logloss:0.24975	validation_0-roc_auc_score:0.75051
# [88]	validation_0-logloss:0.24983	validation_0-roc_auc_score:0.75049
# [89]	validation_0-logloss:0.24984	validation_0-roc_auc_score:0.75053
# [90]	validation_0-logloss:0.24979	validation_0-roc_auc_score:0.75075
# [91]	validation_0-logloss:0.24982	validation_0-roc_auc_score:0.75078
# [92]	validation_0-logloss:0.24981	validation_0-roc_auc_score:0.75085
# [93]	validation_0-logloss:0.24980	validation_0-roc_auc_score:0.75096
# [94]	validation_0-logloss:0.24986	validation_0-roc_auc_score:0.75096
# [95]	validation_0-logloss:0.24992	validation_0-roc_auc_score:0.75091
# [96]	validation_0-logloss:0.24998	validation_0-roc_auc_score:0.75075
# [97]	validation_0-logloss:0.24999	validation_0-roc_auc_score:0.75067
# [98]	validation_0-logloss:0.24998	validation_0-roc_auc_score:0.75073
# [99]	validation_0-logloss:0.24999	validation_0-roc_auc_score:0.75077
# [0]	validation_0-logloss:0.28734	validation_0-roc_auc_score:0.70747
# [1]	validation_0-logloss:0.27537	validation_0-roc_auc_score:0.71370
# [2]	validation_0-logloss:0.26767	validation_0-roc_auc_score:0.71793
# [3]	validation_0-logloss:0.26280	validation_0-roc_auc_score:0.72147
# [4]	validation_0-logloss:0.25953	validation_0-roc_auc_score:0.72420
# [5]	validation_0-logloss:0.25720	validation_0-roc_auc_score:0.72759
# [6]	validation_0-logloss:0.25580	validation_0-roc_auc_score:0.72940
# [7]	validation_0-logloss:0.25485	validation_0-roc_auc_score:0.73055
# [8]	validation_0-logloss:0.25384	validation_0-roc_auc_score:0.73333
# [9]	validation_0-logloss:0.25305	validation_0-roc_auc_score:0.73560
# [10]	validation_0-logloss:0.25229	validation_0-roc_auc_score:0.73809
# [11]	validation_0-logloss:0.25192	validation_0-roc_auc_score:0.73894
# [12]	validation_0-logloss:0.25158	validation_0-roc_auc_score:0.74031
# [13]	validation_0-logloss:0.25132	validation_0-roc_auc_score:0.74127
# [14]	validation_0-logloss:0.25106	validation_0-roc_auc_score:0.74201
# [15]	validation_0-logloss:0.25078	validation_0-roc_auc_score:0.74280
# [16]	validation_0-logloss:0.25062	validation_0-roc_auc_score:0.74343
# [17]	validation_0-logloss:0.25055	validation_0-roc_auc_score:0.74377
# [18]	validation_0-logloss:0.25049	validation_0-roc_auc_score:0.74421
# [19]	validation_0-logloss:0.25035	validation_0-roc_auc_score:0.74488
# [20]	validation_0-logloss:0.25037	validation_0-roc_auc_score:0.74478
# [21]	validation_0-logloss:0.25018	validation_0-roc_auc_score:0.74548
# [22]	validation_0-logloss:0.25012	validation_0-roc_auc_score:0.74562
# [23]	validation_0-logloss:0.25004	validation_0-roc_auc_score:0.74591
# [24]	validation_0-logloss:0.25001	validation_0-roc_auc_score:0.74598
# [25]	validation_0-logloss:0.25003	validation_0-roc_auc_score:0.74618
# [26]	validation_0-logloss:0.25005	validation_0-roc_auc_score:0.74612
# [27]	validation_0-logloss:0.24998	validation_0-roc_auc_score:0.74647
# [28]	validation_0-logloss:0.25002	validation_0-roc_auc_score:0.74632
# [29]	validation_0-logloss:0.24996	validation_0-roc_auc_score:0.74647
# [30]	validation_0-logloss:0.24993	validation_0-roc_auc_score:0.74676
# [31]	validation_0-logloss:0.24995	validation_0-roc_auc_score:0.74660
# [32]	validation_0-logloss:0.24997	validation_0-roc_auc_score:0.74651
# [33]	validation_0-logloss:0.24998	validation_0-roc_auc_score:0.74645
# [34]	validation_0-logloss:0.24987	validation_0-roc_auc_score:0.74683
# [35]	validation_0-logloss:0.24994	validation_0-roc_auc_score:0.74666
# [36]	validation_0-logloss:0.24993	validation_0-roc_auc_score:0.74667
# [37]	validation_0-logloss:0.24991	validation_0-roc_auc_score:0.74668
# [38]	validation_0-logloss:0.24991	validation_0-roc_auc_score:0.74683
# [39]	validation_0-logloss:0.24996	validation_0-roc_auc_score:0.74675
# [40]	validation_0-logloss:0.24994	validation_0-roc_auc_score:0.74684
# [41]	validation_0-logloss:0.24995	validation_0-roc_auc_score:0.74676
# [42]	validation_0-logloss:0.24996	validation_0-roc_auc_score:0.74679
# [43]	validation_0-logloss:0.24998	validation_0-roc_auc_score:0.74678
# [44]	validation_0-logloss:0.24989	validation_0-roc_auc_score:0.74731
# [45]	validation_0-logloss:0.24968	validation_0-roc_auc_score:0.74810
# [46]	validation_0-logloss:0.24976	validation_0-roc_auc_score:0.74792
# [47]	validation_0-logloss:0.24974	validation_0-roc_auc_score:0.74795
# [48]	validation_0-logloss:0.24988	validation_0-roc_auc_score:0.74771
# [49]	validation_0-logloss:0.24987	validation_0-roc_auc_score:0.74774
# [50]	validation_0-logloss:0.24990	validation_0-roc_auc_score:0.74764
# [51]	validation_0-logloss:0.24995	validation_0-roc_auc_score:0.74748
# [52]	validation_0-logloss:0.25001	validation_0-roc_auc_score:0.74729
# [53]	validation_0-logloss:0.25006	validation_0-roc_auc_score:0.74719
# [54]	validation_0-logloss:0.25017	validation_0-roc_auc_score:0.74687
# [55]	validation_0-logloss:0.25015	validation_0-roc_auc_score:0.74716
# [56]	validation_0-logloss:0.25021	validation_0-roc_auc_score:0.74708
# [57]	validation_0-logloss:0.25027	validation_0-roc_auc_score:0.74689
# [58]	validation_0-logloss:0.25029	validation_0-roc_auc_score:0.74707
# [59]	validation_0-logloss:0.25033	validation_0-roc_auc_score:0.74689
# [60]	validation_0-logloss:0.25042	validation_0-roc_auc_score:0.74659
# [61]	validation_0-logloss:0.25040	validation_0-roc_auc_score:0.74662
# [62]	validation_0-logloss:0.25041	validation_0-roc_auc_score:0.74665
# [63]	validation_0-logloss:0.25045	validation_0-roc_auc_score:0.74647
# [64]	validation_0-logloss:0.25045	validation_0-roc_auc_score:0.74637
# [65]	validation_0-logloss:0.25050	validation_0-roc_auc_score:0.74611
# [66]	validation_0-logloss:0.25055	validation_0-roc_auc_score:0.74587
# [67]	validation_0-logloss:0.25062	validation_0-roc_auc_score:0.74562
# [68]	validation_0-logloss:0.25058	validation_0-roc_auc_score:0.74577
# [69]	validation_0-logloss:0.25066	validation_0-roc_auc_score:0.74543
# [70]	validation_0-logloss:0.25068	validation_0-roc_auc_score:0.74534
# [71]	validation_0-logloss:0.25067	validation_0-roc_auc_score:0.74539
# [72]	validation_0-logloss:0.25072	validation_0-roc_auc_score:0.74528
# [73]	validation_0-logloss:0.25082	validation_0-roc_auc_score:0.74504
# [74]	validation_0-logloss:0.25090	validation_0-roc_auc_score:0.74484
# [75]	validation_0-logloss:0.25097	validation_0-roc_auc_score:0.74464
# [76]	validation_0-logloss:0.25105	validation_0-roc_auc_score:0.74432
# [77]	validation_0-logloss:0.25099	validation_0-roc_auc_score:0.74462
# [78]	validation_0-logloss:0.25104	validation_0-roc_auc_score:0.74450
# [79]	validation_0-logloss:0.25116	validation_0-roc_auc_score:0.74410
# [80]	validation_0-logloss:0.25119	validation_0-roc_auc_score:0.74411
# [81]	validation_0-logloss:0.25124	validation_0-roc_auc_score:0.74400
# [82]	validation_0-logloss:0.25129	validation_0-roc_auc_score:0.74388
# [83]	validation_0-logloss:0.25122	validation_0-roc_auc_score:0.74423
# [84]	validation_0-logloss:0.25130	validation_0-roc_auc_score:0.74403
# [85]	validation_0-logloss:0.25133	validation_0-roc_auc_score:0.74391
# [86]	validation_0-logloss:0.25141	validation_0-roc_auc_score:0.74373
# [87]	validation_0-logloss:0.25148	validation_0-roc_auc_score:0.74353
# [88]	validation_0-logloss:0.25150	validation_0-roc_auc_score:0.74350
# [89]	validation_0-logloss:0.25153	validation_0-roc_auc_score:0.74345
# [90]	validation_0-logloss:0.25155	validation_0-roc_auc_score:0.74351
# [91]	validation_0-logloss:0.25157	validation_0-roc_auc_score:0.74347
# [92]	validation_0-logloss:0.25163	validation_0-roc_auc_score:0.74329
# [93]	validation_0-logloss:0.25162	validation_0-roc_auc_score:0.74330
# [94]	validation_0-logloss:0.25167	validation_0-roc_auc_score:0.74326
# [95]	validation_0-logloss:0.25169	validation_0-roc_auc_score:0.74322
# [96]	validation_0-logloss:0.25169	validation_0-roc_auc_score:0.74317
# [97]	validation_0-logloss:0.25174	validation_0-roc_auc_score:0.74294
# [98]	validation_0-logloss:0.25182	validation_0-roc_auc_score:0.74281
# [99]	validation_0-logloss:0.25184	validation_0-roc_auc_score:0.74272
# CV AUC: 0.7488378132006434

# %%
collect_model_result(oof_preds, roc_auc_score(y_train, oof_preds), 'xgb')

# %%
import shap
explainer = shap.Explainer(model)
shap_values = explainer(X_train)

# %%
shap_values.values.shape
# Out:
# (307511, 244)

# %%
shap_importance = np.abs(shap_values.values).mean(axis=0)
features = pd.Series(shap_importance, index=X_train.columns).sort_values(ascending=False)
top_features = features[features > 0.01]
print('# Top features:', len(top_features))
print(top_features.head(50))
# Out:
# # Top features: 51
# EXT_SOURCE_3                                        0.3841
# EXT_SOURCE_2                                        0.3450
# AMT_GOODS_PRICE                                     0.2528
# AMT_CREDIT                                          0.2232
# EXT_SOURCE_1                                        0.1585
# DAYS_EMPLOYED                                       0.1092
# DAYS_BIRTH                                          0.1001
# AMT_ANNUITY                                         0.0975
# CODE_GENDER_F                                       0.0825
# FLAG_OWN_CAR_N                                      0.0800
# NAME_EDUCATION_TYPE_Higher education                0.0779
# DAYS_ID_PUBLISH                                     0.0754
# DAYS_LAST_PHONE_CHANGE                              0.0592
# NAME_FAMILY_STATUS_Married                          0.0546
# FLAG_DOCUMENT_3                                     0.0486
# NAME_INCOME_TYPE_Working                            0.0421
# DAYS_REGISTRATION                                   0.0393
# REGION_POPULATION_RELATIVE                          0.0389
# NAME_CONTRACT_TYPE_Cash loans                       0.0377
# FLAG_WORK_PHONE                                     0.0371
# AMT_REQ_CREDIT_BUREAU_QRT                           0.0356
# REGION_RATING_CLIENT_W_CITY                         0.0336
# OWN_CAR_AGE                                         0.0331
# CODE_GENDER_M                                       0.0306
# AMT_INCOME_TOTAL                                    0.0297
# AMT_REQ_CREDIT_BUREAU_YEAR                          0.0297
# ORGANIZATION_TYPE_Self-employed                     0.0239
# YEARS_BEGINEXPLUATATION_MODE                        0.0233
# NAME_EDUCATION_TYPE_Secondary / secondary special   0.0225
# HOUR_APPR_PROCESS_START                             0.0223
# REG_CITY_NOT_LIVE_CITY                              0.0215
# DEF_30_CNT_SOCIAL_CIRCLE                            0.0195
# TOTALAREA_MODE                                      0.0190
# DEF_60_CNT_SOCIAL_CIRCLE                            0.0180
# FLAG_PHONE                                          0.0166
# FLAG_OWN_REALTY_N                                   0.0164
# ORGANIZATION_TYPE_Business Entity Type 3            0.0155
# OCCUPATION_TYPE_Laborers                            0.0153
# YEARS_BEGINEXPLUATATION_MEDI                        0.0151
# NONLIVINGAREA_AVG                                   0.0147
# LANDAREA_MEDI                                       0.0146
# YEARS_BEGINEXPLUATATION_AVG                         0.0143
# LANDAREA_AVG                                        0.0137
# OCCUPATION_TYPE_Core staff                          0.0133
# WEEKDAY_APPR_PROCESS_START_MONDAY                   0.0130
# NAME_TYPE_SUITE_Unaccompanied                       0.0127
# OBS_30_CNT_SOCIAL_CIRCLE                            0.0125
# OBS_60_CNT_SOCIAL_CIRCLE                            0.0117
# WALLSMATERIAL_MODE_Panel                            0.0114
# BASEMENTAREA_MODE                                   0.0114
# dtype: float32

# %% [markdown]
# ### 2.3) LGBMClassifier

# %%
import shap

def cal_shap(model, X):
    explainer = shap.Explainer(model)
    shap_values = explainer(X)
    return shap_values

def cal_top_features(shap_values, X):
    shap_importance = np.abs(shap_values[:, :, 1].values).mean(axis=0)
    features = pd.Series(shap_importance, index=X.columns).sort_values(ascending=False)
    top_features = features[features > 0.01]
    print('# Top features:', len(top_features))
    print(top_features.head(50))
    return features

def get_shap_features(model, X):
    shap_values = cal_shap(model, X)
    features = cal_top_features(shap_values, X)
    return shap_values, features

# %%
X_train, y_train, X_test = prepare_train_test_set(df_train.drop(['TARGET'], axis=1), df_test)
X_train.shape, X_test.shape
# Out:
# ((307511, 244), (48744, 244))

# %%
import lightgbm as lgb

folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
oof_preds = np.zeros(X_train.shape[0])
test_preds = np.zeros(X_test.shape[0])

for train_idx, val_idx in folds.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
    y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]

    model = lgb.LGBMClassifier(n_estimators=1000, learning_rate=0.05, random_state=123, force_col_wise=True)
    model.fit(X_tr, y_tr, eval_set=[(X_val, y_val)], eval_metric='auc')

    oof_preds[val_idx] = model.predict_proba(X_val)[:, 1]
    test_preds += model.predict_proba(X_test)[:, 1] / folds.n_splits

print('CV AUC:', roc_auc_score(y_train, oof_preds))
# Out:
# [LightGBM] [Info] Number of positive: 19860, number of negative: 226148
# [LightGBM] [Info] Total Bins 11410
# [LightGBM] [Info] Number of data points in the train set: 246008, number of used features: 234
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432482
# [LightGBM] [Info] Start training from score -2.432482
# [LightGBM] [Info] Number of positive: 19860, number of negative: 226149
# [LightGBM] [Info] Total Bins 11334
# [LightGBM] [Info] Number of data points in the train set: 246009, number of used features: 234
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432486
# [LightGBM] [Info] Start training from score -2.432486
# [LightGBM] [Info] Number of positive: 19860, number of negative: 226149
# [LightGBM] [Info] Total Bins 11347
# [LightGBM] [Info] Number of data points in the train set: 246009, number of used features: 233
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432486
# [LightGBM] [Info] Start training from score -2.432486
# [LightGBM] [Info] Number of positive: 19860, number of negative: 226149
# [LightGBM] [Info] Total Bins 11308
# [LightGBM] [Info] Number of data points in the train set: 246009, number of used features: 233
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432486
# [LightGBM] [Info] Start training from score -2.432486
# [LightGBM] [Info] Number of positive: 19860, number of negative: 226149
# [LightGBM] [Info] Total Bins 11327
# [LightGBM] [Info] Number of data points in the train set: 246009, number of used features: 233
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432486
# [LightGBM] [Info] Start training from score -2.432486
# CV AUC: 0.7554028714290397

# %%
collect_model_result(oof_preds, roc_auc_score(y_train, oof_preds), 'lgb')

# %%
shap_values, features = get_shap_features(model, X_train)
# Out:
# # Top features: 45
# EXT_SOURCE_3                                        0.3810
# EXT_SOURCE_2                                        0.3332
# AMT_GOODS_PRICE                                     0.2164
# AMT_CREDIT                                          0.1937
# EXT_SOURCE_1                                        0.1610
# DAYS_EMPLOYED                                       0.1018
# DAYS_BIRTH                                          0.0854
# CODE_GENDER_F                                       0.0824
# NAME_EDUCATION_TYPE_HIGHER_EDUCATION                0.0822
# FLAG_OWN_CAR_N                                      0.0778
# AMT_ANNUITY                                         0.0778
# DAYS_ID_PUBLISH                                     0.0719
# NAME_FAMILY_STATUS_MARRIED                          0.0517
# NAME_CONTRACT_TYPE_CASH_LOANS                       0.0466
# DAYS_LAST_PHONE_CHANGE                              0.0464
# FLAG_DOCUMENT_3                                     0.0402
# NAME_INCOME_TYPE_WORKING                            0.0385
# AMT_REQ_CREDIT_BUREAU_QRT                           0.0336
# DAYS_REGISTRATION                                   0.0324
# REGION_POPULATION_RELATIVE                          0.0303
# REGION_RATING_CLIENT_W_CITY                         0.0298
# FLAG_WORK_PHONE                                     0.0291
# CODE_GENDER_M                                       0.0280
# DEF_30_CNT_SOCIAL_CIRCLE                            0.0273
# OWN_CAR_AGE                                         0.0272
# NONLIVINGAREA_AVG                                   0.0263
# ORGANIZATION_TYPE_SELF_EMPLOYED                     0.0220
# HOUR_APPR_PROCESS_START                             0.0210
# AMT_INCOME_TOTAL                                    0.0209
# AMT_REQ_CREDIT_BUREAU_YEAR                          0.0208
# ORGANIZATION_TYPE_BUSINESS_ENTITY_TYPE_3            0.0189
# FLAG_PHONE                                          0.0161
# REG_CITY_NOT_LIVE_CITY                              0.0153
# NONLIVINGAREA_MEDI                                  0.0150
# YEARS_BEGINEXPLUATATION_MODE                        0.0142
# TOTALAREA_MODE                                      0.0137
# YEARS_BEGINEXPLUATATION_AVG                         0.0135
# NAME_EDUCATION_TYPE_SECONDARY___SECONDARY_SPECIAL   0.0132
# OCCUPATION_TYPE_LABORERS                            0.0131
# WEEKDAY_APPR_PROCESS_START_MONDAY                   0.0126
# WALLSMATERIAL_MODE_PANEL                            0.0118
# DEF_60_CNT_SOCIAL_CIRCLE                            0.0109
# WEEKDAY_APPR_PROCESS_START_TUESDAY                  0.0107
# NAME_TYPE_SUITE_UNACCOMPANIED                       0.0104
# YEARS_BEGINEXPLUATATION_MEDI                        0.0101
# dtype: float64

# %% [markdown]
# ### 2.4) LGBMClassifier with category-type features

# %%
def gen_feature_lgb(df_raw, to_fill_zero_cols, to_fill_avg_cols):
    df_object = df_raw.select_dtypes(include='object')
    
    df = df_raw.copy()
    df[df_object.columns] = df_object.astype('category')
    df[to_fill_zero_cols] = df_app_train[to_fill_zero_cols].fillna(0)
    
    ## this method might be forward-looking bias for cross valiation, using for exploration only
    df[to_fill_avg_cols] = df_app_train[to_fill_avg_cols].fillna(df_app_train[to_fill_avg_cols].mean())
    return df

# %%
df_train = gen_feature_lgb(df_app_train, to_fill_zero_cols, to_fill_avg_cols)
df_test = gen_feature_lgb(df_app_test, to_fill_zero_cols, to_fill_avg_cols)

# %%
X_train, y_train, X_test = prepare_train_test_set(df_train.drop(['TARGET'], axis=1), df_test)
X_train.shape, X_test.shape
# Out:
# ((307511, 120), (48744, 120))

# %%
import lightgbm as lgb

folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
oof_preds = np.zeros(X_train.shape[0])
test_preds = np.zeros(X_test.shape[0])

for train_idx, val_idx in folds.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
    y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]

    model = lgb.LGBMClassifier(n_estimators=1000, learning_rate=0.05, random_state=123, force_col_wise=True)
    model.fit(X_tr, y_tr, eval_set=[(X_val, y_val)], eval_metric='auc')

    oof_preds[val_idx] = model.predict_proba(X_val)[:, 1]
    test_preds += model.predict_proba(X_test)[:, 1] / folds.n_splits

print('CV AUC:', roc_auc_score(y_train, oof_preds))
# Out:
# [LightGBM] [Info] Number of positive: 19860, number of negative: 226148
# [LightGBM] [Info] Total Bins 11292
# [LightGBM] [Info] Number of data points in the train set: 246008, number of used features: 116
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432482
# [LightGBM] [Info] Start training from score -2.432482
# [LightGBM] [Info] Number of positive: 19860, number of negative: 226149
# [LightGBM] [Info] Total Bins 11214
# [LightGBM] [Info] Number of data points in the train set: 246009, number of used features: 115
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432486
# [LightGBM] [Info] Start training from score -2.432486
# [LightGBM] [Info] Number of positive: 19860, number of negative: 226149
# [LightGBM] [Info] Total Bins 11231
# [LightGBM] [Info] Number of data points in the train set: 246009, number of used features: 116
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432486
# [LightGBM] [Info] Start training from score -2.432486
# [LightGBM] [Info] Number of positive: 19860, number of negative: 226149
# [LightGBM] [Info] Total Bins 11192
# [LightGBM] [Info] Number of data points in the train set: 246009, number of used features: 116
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432486
# [LightGBM] [Info] Start training from score -2.432486
# [LightGBM] [Info] Number of positive: 19860, number of negative: 226149
# [LightGBM] [Info] Total Bins 11209
# [LightGBM] [Info] Number of data points in the train set: 246009, number of used features: 115
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432486
# [LightGBM] [Info] Start training from score -2.432486
# CV AUC: 0.7545733518383094

# %%
collect_model_result(oof_preds, roc_auc_score(y_train, oof_preds), 'lgb_category')

# %%
shap_values, features = get_shap_features(model, X_train)
# Out:
# # Top features: 42
# EXT_SOURCE_3                   0.3784
# EXT_SOURCE_2                   0.3346
# AMT_GOODS_PRICE                0.2099
# AMT_CREDIT                     0.1835
# EXT_SOURCE_1                   0.1595
# DAYS_EMPLOYED                  0.1241
# ORGANIZATION_TYPE              0.1148
# CODE_GENDER                    0.0985
# NAME_EDUCATION_TYPE            0.0848
# AMT_ANNUITY                    0.0826
# DAYS_BIRTH                     0.0799
# DAYS_ID_PUBLISH                0.0742
# FLAG_OWN_CAR                   0.0739
# OCCUPATION_TYPE                0.0602
# NAME_FAMILY_STATUS             0.0516
# NAME_INCOME_TYPE               0.0514
# DAYS_LAST_PHONE_CHANGE         0.0465
# FLAG_DOCUMENT_3                0.0435
# NAME_CONTRACT_TYPE             0.0402
# AMT_REQ_CREDIT_BUREAU_QRT      0.0346
# WEEKDAY_APPR_PROCESS_START     0.0333
# REGION_POPULATION_RELATIVE     0.0314
# REGION_RATING_CLIENT_W_CITY    0.0313
# DAYS_REGISTRATION              0.0296
# OWN_CAR_AGE                    0.0296
# FLAG_WORK_PHONE                0.0290
# DEF_30_CNT_SOCIAL_CIRCLE       0.0262
# WALLSMATERIAL_MODE             0.0213
# HOUR_APPR_PROCESS_START        0.0209
# AMT_REQ_CREDIT_BUREAU_YEAR     0.0202
# FLAG_PHONE                     0.0197
# AMT_INCOME_TOTAL               0.0195
# REG_CITY_NOT_LIVE_CITY         0.0156
# NONLIVINGAREA_AVG              0.0155
# TOTALAREA_MODE                 0.0136
# NAME_HOUSING_TYPE              0.0121
# FLAG_OWN_REALTY                0.0116
# YEARS_BEGINEXPLUATATION_AVG    0.0115
# NAME_TYPE_SUITE                0.0114
# YEARS_BEGINEXPLUATATION_MEDI   0.0114
# DEF_60_CNT_SOCIAL_CIRCLE       0.0113
# YEARS_BEGINEXPLUATATION_MODE   0.0108
# dtype: float64

# %% [markdown]
# ## Part 3: Model Comparison

# %%
dict_auc
# Out:
# {'logisticregression': 0.7467989136495174}

# %%
df_pred
# Out:
#         TARGET  logisticregression
# 0            1              0.6105
# 1            0              0.0319
# 2            0              0.0317
# 3            0              0.0691
# 4            0              0.0912
# ...        ...                 ...
# 307506       0              0.0851
# 307507       0              0.1180
# 307508       0              0.0543
# 307509       1              0.0577
# 307510       0              0.0745
#
# [307511 rows x 2 columns]
